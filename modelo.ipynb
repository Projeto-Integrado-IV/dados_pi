# %% [markdown]
# <a href="https://colab.research.google.com/github/Projeto-Integrado-IV/dados_pi/blob/main/modelo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Substitua o link abaixo pelo URL do arquivo CSV no GitHub
url = 'https://github.com/Projeto-Integrado-IV/dados_pi/raw/refs/heads/main/raw/obitosinfantis_periodo.csv'
url2 = 'https://github.com/Projeto-Integrado-IV/dados_pi/raw/refs/heads/main/raw/obitosinfantis_principais_causas.csv'
# Tente ler o arquivo CSV especificando uma codificação diferente
df = pd.read_csv(url, delimiter=';', encoding='latin1')

# Exibir as primeiras linhas do DataFrame
df.head(10)
# Out:
#    cod_ibge   ano  obitos menores de 1 Ano  obitos menores de 7 dias  \
# 0   3500000  2022                      4.0                       4.0
# 1   3500105  2022                      4.0                       2.0
# 2   3500204  2022                      0.0                       0.0
# 3   3500303  2022                      3.0                       2.0
# 4   3500402  2022                      1.0                       0.0
# 5   3500501  2022                      1.0                       1.0
# 6   3500550  2022                      0.0                       0.0
# 7   3500600  2022                      NaN                       NaN
# 8   3500709  2022                      3.0                       2.0
# 9   3500758  2022                      1.0                       1.0
#
#    obitos de 28 dias a 364 dias  obitos de 7 a 27 dias  \
# 0                           0.0                    0.0
# 1                           1.0                    1.0
# ...
